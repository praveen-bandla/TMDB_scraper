# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
df = pd.read_csv("results.csv")
df
# Out:
#                     actor                             movie_or_TV_name
# 0    Benedict Cumberbatch                               Doctor Strange
# 1    Benedict Cumberbatch                           The Imitation Game
# 2    Benedict Cumberbatch  Doctor Strange in the Multiverse of Madness
# 3    Benedict Cumberbatch                      Spider-Man: No Way Home
# 4    Benedict Cumberbatch                       Avengers: Infinity War
# ..                    ...                                          ...
# 602       Keira Knightley   Pirates of the Caribbean: Dead Man's Chest
# 603       Keira Knightley     Pirates of the Caribbean: At World's End
# 604       Keira Knightley                                    Atonement
# 605       Keira Knightley                                Anna Karenina
# 606       Keira Knightley                           A Dangerous Method
#
# [607 rows x 2 columns]

# %%
df_analysis = df.groupby(['movie_or_TV_name']).agg('count').reset_index()
df_analysis.sort_values(by = 'actor', ascending = False, inplace = True)
df_analysis.rename(columns = {"actor": 'Number of actors'}, inplace = True)
df_analysis.reset_index(drop = True, inplace = True)
df_analysis = df_analysis[1:]
df_analysis
# Out:
#                               movie_or_TV_name  Number of actors
# 1                            London Has Fallen                 7
# 2                                      Macbeth                 7
# 3                                Me Before You                 6
# 4         The Woman in Black 2: Angel of Death                 5
# 5               Jurassic World: Fallen Kingdom                 5
# ..                                         ...               ...
# 412                                Headhunters                 1
# 413   Harry Potter and the Philosopher's Stone                 1
# 414  Harry Potter and the Order of the Phoenix                 1
# 415        Harry Potter and the Goblet of Fire                 1
# 416                                   Æon Flux                 1
#
# [416 rows x 2 columns]

# %%
df_analysis[df_analysis['Number of actors'] > 2]
# Out:
#                             movie_or_TV_name  Number of actors
# 1                          London Has Fallen                 7
# 2                                    Macbeth                 7
# 3                              Me Before You                 6
# 4       The Woman in Black 2: Angel of Death                 5
# 5             Jurassic World: Fallen Kingdom                 5
# 6                          Bohemian Rhapsody                 5
# 7                              The Foreigner                 5
# 8                          The King's Speech                 5
# 9         Sherlock Holmes: A Game of Shadows                 4
# 10                                Kick-Ass 2                 3
# 11                               Red Sparrow                 3
# 12  Harry Potter and the Prisoner of Azkaban                 3
# 13                          Assassin's Creed                 3
# 14                           A Monster Calls                 3
# ...

# %%
url = 'https://www.themoviedb.org/movie/205596-the-imitation-game?language=en-US'
fullcastandcrew = 'https://www.themoviedb.org/movie/205596-the-imitation-game/cast?language=en-US'

# %%
r = requests.get(fullcastandcrew, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'})
soup = BeautifulSoup(r.content, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <title>
#    The Imitation Game (2014) - Cast &amp; Crew — The Movie Database (TMDB)
#   </title>
#   <meta content="on" http-equiv="cleartype"/>
#   <meta charset="utf-8"/>
#   <meta content="Movies, TV Shows, Streaming, Reviews, API, Actors, Actresses, Photos, User Ratings, Synopsis, Trailers, Teasers, Credits, Cast" name="keywords"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="Based on the real life story of legendary cryptanalyst Alan Turing, the film portrays the nail-biting race against time by Turing and his brilliant team of code-breakers at Britain's top-secret Government Code and Cypher School at Bletchley Park, during the darkest days of World War II." name="description"/>
# ...

# %%
links = soup.find_all('ol', class_ = 'people credits')

# %%
l2 = links[0].find_all('div', class_= 'info')

# %%
l3 = []
for a in l2:
    l3.append(a.find('a'))

# %%
len(l3)
# Out:
# 63
